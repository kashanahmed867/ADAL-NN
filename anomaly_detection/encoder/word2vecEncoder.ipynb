# %%
# !pip install fastText
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastText
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 5.7 MB/s
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.1-py3-none-any.whl (216 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from fastText) (57.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from fastText) (1.21.6)
# Building wheels for collected packages: fastText
#   Building wheel for fastText (setup.py) ... done
#   Created wheel for fastText: filename=fasttext-0.9.2-cp38-cp38-linux_x86_64.whl size=3133868 sha256=f0d8cf525b937db0dc362ba3721b368f2c9c946a466bfd8898cb62384309f718
#   Stored in directory: /root/.cache/pip/wheels/93/61/2a/c54711a91c418ba06ba195b1d78ff24fcaad8592f2a694ac94
# Successfully built fastText
# Installing collected packages: pybind11, fastText
# Successfully installed fastText-0.9.2 pybind11-2.10.1

# %%
from tqdm import tqdm
import csv
import pickle
import re
import random
import fasttext
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import numpy as np
import gensim
import argparse

# %%
class SemanticVec:

    def __init__(self, w2vmodel, t2wFN, embed_dim):
        # self.corpus = corpus
        self.embed_dim = embed_dim
        self.w2vmodel = w2vmodel
        self.t2wFN = t2wFN
        self.stop_words = ['a', 'the']

    def csr_todense(self, n_row, n_col, Ap, Aj, Ax):
        result = np.zeros([n_row, n_col])
        for i in range(0, n_row):
            for j in range(Ap[i], Ap[i + 1]):
                result[Aj[j]] += Ax[j]
        return result

    def run(self):
        # loadtemplate()
        # t2w = gensim.models.KeyedVectors.load_word2vec_format(self.w2vmodel, binary=False, encoding='utf8')
        t2w = pickle.load(open(self.t2wFN, 'rb'))
        # preprocess()
        # import pdb; pdb.set_trace()
        self.preprocess(t2w)
        # word2vec()
        self.word2vec()
        # calTFIDF()
        weight, vectorizer = self.calTFIDF()
        senvec = dict()
        print('Semantic Vectorization...')
        #import pdb; pdb.set_trace()
        i = 0
        for idx, wvs in tqdm(self.vecs.items()):
            # print(idx)
            # import pdb; pdb.set_trace()
            vec = np.zeros(self.embed_dim)
            w = weight[i]
            i += 1
            v = np.zeros(self.embed_dim)
            for ii, wv in enumerate(wvs):
                wi = vectorizer.vocabulary_.get(t2w[idx][ii])
                # if type(wi) is np.int64:
                if type(wi) is int:
                    ww = w[wi]
                else:
                    ww = 0
                v = v + np.array(ww * wv)
            v = v.astype('float64')
            senvec[idx] = v
            print(v.dtype)
        # print(senvec.shape)
        return senvec


    def preprocess(self, t2w):
        print('Preprocessing...')
        self.t2w_filter = dict()
        for t, words in tqdm(t2w.items()):
            print(t)
            print(words)
            self.t2w_filter[t] = [word for word in words if word not in self.stop_words]

    def word2vec(self):
        print('Word Embedding...')
        # pre-trained on Common Crawl Corpus dataset using the FastText algorithm
        model = fasttext.load_model(self.w2vmodel)
        # model = gensim.models.KeyedVectors.load_word2vec_format(self.w2vmodel, binary=False, encoding='utf8')
        self.vecs = dict()
        for idx, line in tqdm(self.t2w_filter.items()):
            vec = list()
            for word in line:
                vec.append(model[word])
            self.vecs[idx] = vec

    def calTFIDF(self):
        print('Calculating TFIDF weight...')
        vectorizer = CountVectorizer()
        corpus = list()
        for idx, lines in self.t2w_filter.items():
            corpus.append(' '.join(lines))
            # corpus = [l for idx, lines in self.t2w_filter.iterms() l = ' '.join(lines)]
        X = vectorizer.fit_transform(corpus)
        # word = vectorizer.get_feature_names()
        # import pdb; pdb.set_trace()
        transformer = TfidfTransformer()
        # print transformer
        # import ipdb; ipdb.set_trace()
        tfidf = transformer.fit_transform(X)
        M, N = tfidf._swap(tfidf.shape)
        # weight = self.csr_todense(M, N, tfidf.indptr, tfidf.indices, tfidf.data)
        weight = tfidf.toarray()
        # import ipdb; ipdb.set_trace()
        return weight, vectorizer

# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M-subword.zip
# !unzip crawl-300d-2M-subword.zip
# Out:
# --2022-12-08 19:33:28--  https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M-subword.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 104.22.74.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5828358084 (5.4G) [application/zip]
# Saving to: ‘crawl-300d-2M-subword.zip’
#
# crawl-300d-2M-subwo 100%[===================>]   5.43G  11.1MB/s    in 9m 54s
#
# 2022-12-08 19:43:23 (9.36 MB/s) - ‘crawl-300d-2M-subword.zip’ saved [5828358084/5828358084]
#
# Archive:  crawl-300d-2M-subword.zip
#   inflating: crawl-300d-2M-subword.vec
#   inflating: crawl-300d-2M-subword.bin

# %%
# /content/sample_data/template2words.pkl
# parser = argparse.ArgumentParser()
# parser.add_argument('-ratio', default=1, type=float)
# args = parser.parse_args()
# ratio =  args.ratio
ratio = 1
w2vmodelPath = '/content/crawl-300d-2M-subword.bin'
t2wPath = '/content/sample_data/templates.pkl'
#t2wPath = '../data/hdfs_' + str(ratio) + '/my_hdfs_' + str(ratio) + '_template2words.pkl'
embed_dim = 300
model = SemanticVec(w2vmodelPath, t2wPath, embed_dim)
vecs = model.run()
pickle.dump(vecs, open('/content/sample_data/sentence2vec.pkl', 'wb'))
#pickle.dump(vecs, open('../data/hdfs_' + str(ratio) + '/sentence2vec.pkl', 'wb'))
# Out:
# Preprocessing...
# 100%|██████████| 112/112 [00:00<00:00, 29716.73it/s]
# 0
# ['instruction', 'cache', 'parity', 'error', 'corrected']
# 1
# ['<*>', 'double-hummer', 'alignment', 'exceptions']
# 2
# ['CE', 'sym', '<*>', ',', 'at', '<*>', ',', 'mask', '<*>']
# 3
# ['ciod', ':', 'failed', 'to', 'read', 'message', 'prefix', 'on', 'control', 'stream', '(CioStream', 'socket', 'to', '<*>']
# 4
# ['generating', '<*>']
# 5
# ['force', 'load/store', 'alignment...............0']
# 6
# ['ciod', ':', 'cpu', '<*>', 'at', 'treeaddr', '<*>', 'sent', 'unrecognized', 'message', '0xffffffff']
# 7
# ['ciod', ':', 'LOGIN', '<*>', 'failed', ':', 'No', 'such', 'file', 'or', 'directory']
# 8
# ['<*>', 'ddr', 'errors(s)', 'detected', 'and', 'corrected', 'on', 'rank', '<*>', ',', 'symbol', '<*>', ',', 'bit', '<*>']
# 9
# ['data', 'TLB', 'error', 'interrupt']
# 10
# ['ciod', ':', 'Message', 'code', '<*>', 'is', 'not', '<*>', 'or', '<*>']
# 11
# ['data', 'storage', 'interrupt']
# 12
# ['instruction', 'address', '<*>', '<*>']
# 13
# ['data', 'address', '<*>', '<*>']
# 14
# ['machine', 'check', '<*>', '<*>']
# 15
# ['program', 'interrupt', ':', 'illegal', '<*>']
# 16
# ['exception', 'syndrome', 'register', ':', '<*>']
# 17
# ['data', 'store', 'interrupt', 'caused', 'by', '<*>']
# 18
# ['program', 'interrupt', ':', 'privileged', 'instruction...0']
# 19
# ['program', 'interrupt', ':', 'trap', 'instruction.........0']
# 20
# ['program', 'interrupt', ':', 'imprecise', 'exception......0']
# 21
# ['store', 'operation.............................1']
# 22
# ['machine', 'state', 'register', ':', '0x00002000']
# 23
# ['problem', 'state', '(0', '=', 'sup', ',', '<*>', '=', 'usr).......0']
# 24
# ['floating', 'point', 'instr.', 'enabled.....1']
# 25
# ['auxiliary', 'processor.........................0']
# 26
# ['floating', 'pt', 'ex', 'mode', '<*>', 'enable......0']
# 27
# ['program', 'interrupt', ':', 'unimplemented', 'operation..0']
# 28
# ['debug', 'interrupt', 'enable............0']
# 29
# ['byte', 'ordering', 'exception.....................0']
# 30
# ['core', 'configuration', 'register', ':', '0x00002000']
# 31
# ['program', 'interrupt', ':', 'fp', 'cr', 'update.............0']
# 32
# ['guaranteed', 'instruction', 'cache', 'block', 'touch.0']
# 33
# ['program', 'interrupt', ':', 'fp', 'cr', 'field', '.............0']
# 34
# ['guaranteed', 'data', 'cache', 'block', 'touch........1']
# 35
# ['icache', 'prefetch', '<*>']
# 36
# ['wait', 'state', 'enable.................0']
# 37
# ['critical', 'input', 'interrupt', 'enable...0']
# 38
# ['special', 'purpose', 'registers', ':']
# 39
# ['lr', ':', '00004ed0', 'cr', ':', '<*>', 'xer', ':', '<*>', 'ctr', ':', '<*>']
# 40
# ['rts', 'internal', 'error']
# 41
# ['debug', 'wait', 'enable.................0']
# 42
# ['disable', 'store', 'gathering..................0']
# 43
# ['total', 'of', '<*>', 'ddr', 'error(s)', 'detected', 'and', 'corrected']
# 44
# ['ciod', ':', 'Error', 'loading', '<*>', ':', 'invalid', 'or', 'missing', 'program', 'image', ',', 'No', 'such', 'file', 'or', 'directory']
# 45
# ['ciod', ':', 'Error', 'creating', 'node', 'map', 'from', 'file', '/p/gb2/cabot/miranda/newmaps/8k_128x64x1_8x4x4.map', ':', 'No', 'child', 'processes']
# 46
# ['program', 'interrupt']
# 47
# ['Node', 'card', 'is', 'not', 'fully', 'functional']
# 48
# ['ciod', ':', 'Error', 'creating', 'node', 'map', 'from', 'file', '/p/gb2/welcome3/32k_128x256x1_8x4x4.map', ':', 'Bad', 'file', 'descriptor']
# 49
# ['Ido', 'chip', 'status', 'changed', ':', 'FF', ':', 'F2', ':', '9F', ':', '<*>', ':', '<*>', ':', '<*>', ':', '<*>', ':', '0D', ':', '<*>', ':', '<*>', ':', '<*>', ':', '<*>', 'ip', '=', '<*>', 'v', '=', '<*>', 't', '=', '<*>', 'status', '=', 'M', '<*>', '<*>', 'PDT', '<*>']
# 50
# ['Can', 'not', 'get', 'assembly', 'information', 'for', 'node', 'card']
# 51
# ['ciod', ':', 'Missing', 'or', 'invalid', 'fields', 'on', 'line', '<*>', 'of', 'node', 'map', 'file', '<*>']
# 52
# ['<*>', 'torus', 'receiver', '<*>', 'input', 'pipe', 'error(s)', '(dcr', '<*>', 'detected', 'and', 'corrected']
# 53
# ['ciod', ':', 'duplicate', 'canonical-rank', '<*>', 'to', 'logical-rank', '<*>', 'mapping', 'at', 'line', '<*>', 'of', 'node', 'map', 'file', '/p/gb2/pakin1/sweep3d-5x5x400-10mk-3mmi-1024pes-sweep/sweep.map']
# 54
# ['ciod', ':', 'Error', 'creating', 'node', 'map', 'from', 'file', '/p/gb2/pakin1/sweep3d-5x5x400-10mk-3mmi-1024pes-xyzt/xyzt.map', ':', 'Block', 'device', 'required']
# 55
# ['rts', 'panic!', '-', 'stopping', 'execution']
# 56
# ['ciod', ':', 'Error', 'creating', 'node', 'map', 'from', 'file', '/home/pakin1/sweep3d-2.2b/results/random1-8x32x32x2.map', ':', 'Permission', 'denied']
# 57
# ['ciod', ':', 'Z', 'coordinate', '<*>', 'exceeds', 'physical', 'dimension', '<*>', 'at', 'line', '<*>', 'of', 'node', 'map', 'file', '/p/gb2/pakin1/contention-32768cpes-torus/xyzt-1x1x32768x1.map']
# 58
# ['rts', ':', 'kernel', 'terminated', 'for', 'reason', '1001rts', ':', 'bad', 'message', 'header', ':', 'invalid', 'cpu', ',', 'type', '=', '<*>', ',', 'cpu', '=', '<*>', ',', 'index', '=', '<*>', ',', 'total', '=', '<*>']
# 59
# ['<*>', 'floating', 'point', 'alignment', 'exceptions']
# 60
# ['New', 'ido', 'chip', 'inserted', 'into', 'the', 'database', ':', 'FF', ':', 'F2', ':', '9F', ':', '<*>', ':', '<*>', ':', '<*>', ':', '<*>', ':', '0D', ':', '<*>', ':', '<*>', ':', '<*>', ':', '<*>', 'ip', '=', '<*>', 'v', '=', '<*>', 't', '=', '<*>']
# 61
# ['NodeCard', 'is', 'not', 'fully', 'functional']
# 62
# ['Node', 'card', 'status', ':', 'ALERT', '<*>', ',', 'ALERT', '<*>', ',', 'ALERT', '<*>', ',', 'ALERT', '<*>', 'is', '(are)', 'active.', 'Clock', 'Mode', 'is', 'Low.', 'Clock', 'Select', 'is', 'Midplane.', 'Phy', 'JTAG', 'Reset', 'is', 'asserted.', 'ASIC', 'JTAG', 'Reset', 'is', 'not', 'asserted.', 'Temperature', 'Mask', 'is', 'not', 'active.', 'No', 'temperature', 'error.', 'Temperature', 'Limit', 'Error', 'Latch', 'is', 'clear.', 'PGOOD', 'is', 'asserted.', 'PGOOD', 'error', 'latch', 'is', 'clear.', 'MPGOOD', 'is', 'OK.', 'MPGOOD', 'error', 'latch', 'is', 'clear.', 'The', '2.5', 'volt', 'rail', 'is', 'OK.', 'The', '1.5', 'volt', 'rail', 'is', 'OK.']
# 63
# ['Node', 'card', 'VPD', 'check', ':', '<*>', 'node', 'in', 'processor', 'card', 'slot', '<*>', 'do', 'not', 'match.', 'VPD', 'ecid', '<*>', ',', 'found', '<*>']
# 64
# ['idoproxydb', 'hit', 'ASSERT', 'condition', ':', 'ASSERT', 'expression', '=', '<*>', 'Source', 'file', '=', 'idotransportmgr.cpp', 'Source', 'line', '=', '<*>', 'Function', '=', 'int', 'IdoTransportMgr', ':', ':', 'SendPacket(IdoUdpMgr*', ',', 'BglCtlPavTrace*)']
# 65
# ['Node', 'card', 'status', ':', 'no', 'ALERTs', 'are', 'active.', 'Clock', 'Mode', 'is', 'Low.', 'Clock', 'Select', 'is', 'Midplane.', 'Phy', 'JTAG', 'Reset', 'is', 'asserted.', 'ASIC', 'JTAG', 'Reset', 'is', 'asserted.', 'Temperature', 'Mask', 'is', 'not', 'active.', 'No', 'temperature', 'error.', 'Temperature', 'Limit', 'Error', 'Latch', 'is', 'clear.', 'PGOOD', 'IS', 'NOT', 'ASSERTED.', 'PGOOD', 'ERROR', 'LATCH', 'IS', 'ACTIVE.', 'MPGOOD', 'IS', 'NOT', 'OK.', 'MPGOOD', 'ERROR', 'LATCH', 'IS', 'ACTIVE.', 'The', '2.5', 'volt', 'rail', 'is', 'OK.', 'The', '1.5', 'volt', 'rail', 'is', 'OK.']
# 66
# ['PrepareForService', 'shutting', 'down', 'NodeCard(mLctn(R25-M1-N2)', ',', 'mCardSernum(203231503833343000000000594c31304b34333431303158)', ',', 'mLp(FF', ':', 'F2', ':', '9F', ':', '<*>', ':', 'CF', ':', '0F', ':', '<*>', ':', '0D', ':', '<*>', ':', 'E9', ':', '<*>', ':', 'F0)', ',', 'mIp(10.2.2.80)', ',', 'mType(4))', 'as', 'part', 'of', 'Service', 'Action', '<*>']
# 67
# ['rts', 'tree/torus', 'link', 'training', 'failed', ':', 'wanted', ':', 'B', 'C', 'X+', 'X-', 'Y+', 'Y-', 'Z+', 'Z-', 'got', ':', 'B', 'C', 'X-', 'Y-', 'Z+', 'Z-']
# 68
# ['<*>', 'tree', 'receiver', '<*>', 'in', 're-synch', 'state', 'event(s)', '(dcr', '0x019a)', 'detected']
# 69
# ['ciod', ':', 'Error', 'loading', '<*>', ':', 'invalid', 'or', 'missing', 'program', 'image', ',', 'Exec', 'format', 'error']
# 70
# ['ciod', ':', 'Error', 'reading', 'message', 'prefix', 'after', 'LOAD_MESSAGE', 'on', 'CioStream', 'socket', 'to', '<*>', ':', 'Link', 'has', 'been', 'severed']
# 71
# ['rts', ':', 'kernel', 'terminated', 'for', 'reason', '<*>']
# 72
# ['ciod', ':', 'generated', '<*>', 'core', 'files', 'for', 'program', '<*>']
# 73
# ['iar', '<*>', 'dear', '<*>']
# 74
# ['NFS', 'Mount', 'failed', 'on', '<*>', ',', 'slept', '<*>', 'seconds', ',', 'retrying', '(1)']
# 75
# ['Lustre', 'mount', 'FAILED', ':', '<*>', ':', 'point', '/p/gb1']
# 76
# ['ciod', ':', 'pollControlDescriptors', ':', 'Detected', 'the', 'debugger', 'died.']
# 77
# ['ciod', ':', 'In', 'packet', 'from', 'node', '91.0', '(R62-M1-Nf-C', ':', 'J03-U11)', ',', 'message', 'code', '<*>', 'is', 'not', '<*>', 'or', '<*>', '(softheader', '=', '003b005b', '<*>', '<*>', '00000000)']
# 78
# ['suppressing', 'further', 'interrupts', 'of', 'same', 'type']
# 79
# ['rts', ':', 'bad', 'message', 'header', ':', 'expecting', 'type', '<*>', 'instead', 'of', 'type', '<*>', '(softheader', '=', '00131db8', '81aa0003', '<*>', '00000000)', 'PSR0', '=', '00001f01', 'PSR1', '=', '<*>', 'PRXF', '=', '<*>', 'PIXF', '=', '<*>']
# 80
# ['critical', 'input', 'interrupt', '(unit', '=', '0x0b', 'bit', '=', '<*>', ':', 'warning', 'for', 'torus', '<*>', 'wire']
# 81
# ['ciod', ':', 'Error', 'loading', '<*>', ':', 'invalid', 'or', 'missing', 'program', 'image', ',', 'Permission', 'denied']
# 82
# ['data', 'cache', 'search', 'parity', 'error', 'detected.', 'attempting', 'to', 'correct']
# 83
# ['shutdown', 'complete']
# 84
# ['Error', 'receiving', 'packet', 'on', 'tree', 'network', ',', 'expecting', 'type', '<*>', 'instead', 'of', 'type', '<*>', '(softheader', '=', '<*>', '<*>', '<*>', '00000000)', 'PSR0', '=', '<*>', 'PSR1', '=', '<*>', 'PRXF', '=', '<*>', 'PIXF', '=', '<*>']
# 85
# ['<*>', 'L3', 'EDRAM', 'error(s)', '(dcr', '0x0157)', 'detected', 'and', 'corrected']
# 86
# ['critical', 'input', 'interrupt', '(unit', '=', '0x0b', 'bit', '=', '0x0a)', ':', 'warning', 'for', 'torus', 'z+', 'wire', ',', 'suppressing', 'further', 'interrupts', 'of', 'same', 'type']
# 87
# ['<*>', 'torus', 'sender', 'z-', 'retransmission', 'error(s)', '(dcr', '0x02f9)', 'detected', 'and', 'corrected', 'over', '<*>', 'seconds']
# 88
# ['ciod', ':', 'Received', 'signal', '<*>', ',', 'code', '=', '<*>', ',', 'errno', '=', '<*>', ',', 'address', '=', '<*>']
# 89
# ['Lustre', 'mount', 'FAILED', ':', '<*>', ':', 'block_id', ':', 'location']
# 90
# ['MACHINE', 'CHECK', 'DCR', 'read', 'timeout', '(mc', '=', 'e08x', 'iar', '0x00000000', 'lr', '0xc00045a4)']
# 91
# ['ciod', ':', 'Error', 'reading', 'message', 'prefix', 'on', 'CioStream', 'socket', 'to', '<*>', ',', 'Connection', 'timed', 'out']
# 92
# ['ciod', ':', 'Error', 'reading', 'message', 'prefix', 'on', 'CioStream', 'socket', 'to', '<*>', ',', 'Connection', 'reset', 'by', 'peer']
# 93
# ['dbcr0', '=', '0x00000000', 'dbsr', '=', '0x00000000', 'ccr0', '=', '0x40002000']
# 94
# ['ciod', ':', 'Error', 'reading', 'message', 'prefix', 'on', 'CioStream', 'socket', 'to', '<*>', ',', 'Link', 'has', 'been', 'severed']
# 95
# ['r24', '=', '0x0ffea4c8', 'r25', '=', '0x00000003', 'r26', '=', '0x0000000f', 'r27', '=', '0xffffd000']
# 96
# ['<*>', 'tree', 'receiver', '<*>', 'in', 're-synch', 'state', 'event(s)', '(dcr', '0x0185)', 'detected', 'over', '<*>', 'seconds']
# 97
# ['<*>', 'microseconds', 'spent', 'in', 'the', 'rbs', 'signal', 'handler', 'during', '<*>', 'calls.', '<*>', 'microseconds', 'was', 'the', 'maximum', 'time', 'for', 'a', 'single', 'instance', 'of', 'a', 'correctable', 'ddr.']
# 98
# ['<*>', 'total', 'interrupts.', '<*>', 'critical', 'input', 'interrupts.', '<*>', 'microseconds', 'total', 'spent', 'on', 'critical', 'input', 'interrupts', ',', '<*>', 'microseconds', 'max', 'time', 'in', 'a', 'critical', 'input', 'interrupt.']
# 99
# ['<*>', 'ddr', 'error(s)', 'detected', 'and', 'corrected', 'on', 'rank', '<*>', ',', 'symbol', '<*>', 'over', '<*>', 'seconds']
# 100
# ['PrepareForService', 'shutting', 'down', 'Node', 'card(mLctn(R10-M1-N2)', ',', 'mCardSernum(203231503833343000000000594c31304b34323934303257)', ',', 'mLp(FF', ':', 'F2', ':', '9F', ':', '<*>', ':', 'E0', ':', 'DA', ':', '<*>', ':', '0D', ':', '<*>', ':', 'E9', ':', '1F', ':', '25)', ',', 'mIp(10.1.1.164)', ',', 'mType(4))', 'as', 'part', 'of', 'Service', 'Action', '<*>']
# 101
# ['Kernel', 'detected', '<*>', 'integer', 'alignment', 'exceptions', '<*>', 'iar', '<*>', ',', 'dear', '<*>', '<*>', 'iar', '<*>', ',', 'dear', '<*>', '<*>', 'iar', '<*>', ',', 'dear', '<*>', '<*>', 'iar', '<*>', ',', 'dear', '<*>', '<*>', 'iar', '<*>', ',', 'dear', '<*>', '<*>', 'iar', '<*>', ',', 'dear', '<*>', '<*>', 'iar', '<*>', ',', 'dear', '<*>', '<*>', 'iar', '<*>', ',', 'dear', '<*>']
# 102
# ['total', 'of', '<*>', 'ddr', 'error(s)', 'detected', 'and', 'corrected', 'over', '<*>', 'seconds']
# 103
# ['minus', 'normalized', 'number..................0']
# 104
# ['fraction', 'rounded.........................0']
# 105
# ['critical', 'input', 'interrupt', '(unit', '=', '0x0b', 'bit', '=', '0x17)', ':', 'warning', 'for', 'tree', 'C1', 'wire', ',', 'suppressing', 'further', 'interrupts', 'of', 'same', 'type']
# 106
# ['size', 'of', 'scratchpad', 'portion', 'of', 'L3.........0', '(0M)']
# 107
# ['ciod', ':', 'LOGIN', 'chdir(/p/gb1/stella/RAPTOR/2183)', 'failed', ':', 'Input/output', 'error']
# 108
# ['<*>', 'L3', 'EDRAM', 'error(s)', '(dcr', '0x0157)', 'detected', 'and', 'corrected', 'over', '<*>', 'seconds']
# 109
# ['ciod', ':', 'Error', 'loading', '/g/g24/buber/Yunsic/BlueGene/partad.develf/taddriver.32.exe', ':', 'program', 'image', 'too', 'big', ',', '<*>', '>', '<*>']
# 110
# ['fpr29', '=', '0xffffffff', 'ffffffff', 'ffffffff', 'ffffffff']
# 111
# ['Machine', 'State', 'Register', ':', '0x0002f900']
# Word Embedding...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# 100%|██████████| 112/112 [00:00<00:00, 4864.52it/s]
# Calculating TFIDF weight...
# Semantic Vectorization...
# 100%|██████████| 112/112 [00:00<00:00, 1731.47it/s]
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
pip install bert-serving-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert-serving-client
#   Downloading bert_serving_client-1.10.0-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: pyzmq>=17.1.0 in /usr/local/lib/python3.8/dist-packages (from bert-serving-client) (23.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from bert-serving-client) (1.21.6)
# Installing collected packages: bert-serving-client
# Successfully installed bert-serving-client-1.10.0
